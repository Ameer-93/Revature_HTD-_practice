# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python Basics
#
# ## What is Python?
#
# ```python
#
# def mul(a,b):
#   returning a*b
#
# ```
#
# ---
#
#
# ## Why Python?
#
# ---
#
#
# ## Datatypes in Python
#
# ---

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# mount gdrive

# %%
# !ls sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
api_key = "kfkjdsflkdshflkds8980"

# %%
from google.colab import userdata
api_key = userdata.get('GEMINI_API_KEY')

print(api_key)
# Out:
# kfkjdsflkdshflkds8980

# %%
# this is a comment

a = 20
b = 20.5

# LHS <-- RHS

# %%
print(a)
# Out:
# 20

# %%
a
# Out:
# 20

# %% [markdown]
# # Syntax and Semantic in Python

# %% [markdown]
# ## Syntax
#
# Syntax refers to the set of rules that defines the combinations of symbols that are considered to be correctly structured programs in a language. In simpler terms, **syntax is about the correct arrangement of words and symbols in a code**.
#
# ## Semantics
# Semantics refers to the meaning or the interpretation of the symbols, characters, and commands in a language. **It is about what the code is supposed to do when it runs.**

# %%
10 + 2
# Out:
# 12

# %%
print(10+2)
# Out:
# 12

# %%
10 - 2
# Out:
# 8

# %%
10 * 2
# Out:
# 20

# %%
10 % 3 # modulus operator
# Out:
# 1

# %%
10 / 2 # division
# Out:
# 5.0

# %%
type(5.0)
# Out:
# float

# %%
22/3
# Out:
# 7.333333333333333

# %%
22 // 3 # Floor division
# Out:
# 7

# %%
## Basic Syntax Rules In Python
## Case sensitivity- Python is case sensitive

name="Nikhil"
Name="Sharma"

print(name)
print(Name)
# Out:
# Nikhil
# Sharma

# %% [markdown]
# ### Indentation
# Indentation in Python is used to define the structure and hierarchy of the code. Unlike many other programming languages that use braces `{ }` to delimit blocks of code, Python uses indentation to determine the grouping of statements. This means that all the statements within a block must be indented at the same level.

# %%
def add(a,b):
  # this is the body of the function...
  return a+b

def subtract(a,b):
  return a-b
# Out:
# Running cells with 'Python 3.13.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '"c:/Program Files/Python313/python3.13t.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
def add(a,b):
  pass

# %%
a = 10

if a < 20:
  print("a is less than 20")
  print("a is smaller than 25 ")
else:
  print("a is grater than 20")



## Indentation
## Python uses indentation to define blocks of code. Consistent use of spaces (commonly 4) or a tab is required.
# Out:
# a is less than 20
# a is smaller than 25

# %%
if a < 20:
    print("a is less than 20")
    print("a is smaller than 25 ")
else:
    print("a is grater than 20")

# %%
age = 24


if age>30:
    print("working fine..")
    print("You are above 30")
else:
    print("You are below 30")
# Out:
# You are below 30

# %% [markdown]
# ## Comments

# %%
# single line comment

'''
This is a multiline
comment
!
'''


"""
This is a multiline
comment
!
"""
# Out:
# '\nThis is a multiline\ncomment\n!\n'

# %%
## Line continuation

## use a backslash(\) to continue a statement to the next line

# %%
total = 1 + 2 + 3 + 4 + 5 + \
        4 + 5 + 6 + \
        7

# %%
total
# Out:
# 37

# %%
x = 5; y = 10; z = x+y

print(y)
# Out:
# 10

# %%
a = 10
b = 6.8

# %%
is_admin = True
type(is_admin)
# Out:
# bool

# %% [markdown]
# ### Variables
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them, and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.

# %%
a = 3.14

type(a)
# Out:
# float

# %% [markdown]
# ### Naming Conventions
# 1. vriable names should be descriptive
#
# ```python
# account_holder_name = 'Some Guy' #
# ```
#
# 2. They must start with a letter or an `_` and contains letters, numbers and unserscores
#
#
# 3. variable names are case sesitive
#
# 4. valid variable names
#
# 5. No keywords used as vriable names
# 6. No special characters in the begining as well as in-between
# 7. Names cannot be sperated with a whitespace
#
#
#
#
# `camelCase, PascalCase, snake_case, ALL_UPPER_CASE, lowercase`

# %%
first_name="Nikhil"
last_name="Sharma"

# %%
_name2 = "Minku"

# %%
# Invalid variable names
# 2age=30
# first-name="Nikhil"
# #@name="Nikhil"

# %%
## Python is dynamically typed,type of a variable is determined at runtime
age=24 #int
height=5.10 #float
name="Nikhil" #str
is_student=True #bool

print(type(name))
# Out:
# <class 'str'>

# %%
age = "24"
print(age)
print(type(age))

print('-'*20)

# type casting -> type conversion
age_int = int(age)
print(age_int)
print(type(age_int))
# Out:
# 24
# <class 'str'>
# --------------------
# 24
# <class 'int'>

# %%
n = "Three"
n = 'a'

int(n)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-49-3498058948.py in <cell line: 0>()
#       1 n = 'Three'
#       2
# ----> 3 int(n)
#
# ValueError: invalid literal for int() with base 10: 'Three'

# %%
for char in 'nikhil':
    print(char)
# Out:
# n
# i
# k
# h
# i
# l

# %%
## Dynamic Typing
## Python allows the type of a variable to change as the program executes
var=10 #int
print(var,type(var))

var="Hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %% [markdown]
# ---

# %%
## user input

name = input("Enter your name: ")
age = input("Enter your age: ")
# Out:
# Enter your name: Nikhil
# Enter your age: 24

# %%
print(name, age)
# Out:
# Nikhil 24

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# str

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
# Out:
# Enter your name: Nik
# Enter your age: 24

# %%
type(age)
# Out:
# int

# %% [markdown]
# ## TASK: Build a simple calcucalor

# %% [markdown]
# ---

# %% [markdown]
# # Data Types in Python
#
# ## 1. Introduction
#
# Data types are a classification system that tells the Python interpreter how to handle and store different kinds of data.
# They define:
#
# - The type of operations that can be performed on the data
# - The values that the data can take
# - The amount of memory needed to store the data
# - The methods and attributes available for that data
#
#
# ### Why Data Types Matter
# - **Memory Efficiency**: Different types use different amounts of memory
# - **Operation Validity**: Certain operations only work with specific types
# - **Error Prevention**: Type awareness helps catch bugs early
# - **Performance**: Optimized operations for each type
# - **Code Clarity**: Makes code more readable and maintainable
#
#
# ### Python's Dynamic Typing
#
# Python is dynamically typed, meaning:
#
# - Variables don't need explicit type declarations
# - Types are determined at runtime
# - Variables can change types during execution
# - The interpreter handles type checking automatically

# %%
# Dynamic typing example
x = 5        # x is an integer
x = "hello"  # x is now a string
x = [1,2,3]  # x is now a list

# %% [markdown]
# ## 2. Built-in Data Types Overview
#
# Python has several built-in data types organized into categories:
#
# | Category     | Data Types                   | Mutability                                          |
# | ------------ | ---------------------------- | --------------------------------------------------- |
# | **Numeric**  | int, float, complex          | Immutable                                           |
# | **Text**     | str                          | Immutable                                           |
# | **Boolean**  | bool                         | Immutable                                           |
# | **Sequence** | list, tuple, range           | list (mutable), tuple & range (immutable)           |
# | **Mapping**  | dict                         | Mutable                                             |
# | **Set**      | set, frozenset               | set (mutable), frozenset (immutable)                |
# | **Binary**   | bytes, bytearray, memoryview | bytes (immutable), bytearray & memoryview (mutable) |
# | **None**     | NoneType                     | Immutable                                           |

# %% [markdown]
# ## 3. Numeric Data Types
#
# ### 3.1 Integer (int)
#
# Represents whole numbers of unlimited precision.

# %%
# Integer examples
age = 25
negative = -10
large_number = 123456789012345678901234567890

# Different number bases
binary = 0b1010      # Binary (decimal 10)
octal = 0o12         # Octal (decimal 10)
hexadecimal = 0xa    # Hexadecimal (decimal 10)



# Operations
print(10 + 5)
print(10 - 3)
print(10 * 4)
print(10 // 3)
print(10 % 3)
print(10 ** 2)  # (x ** y) --> x raised to the power y
# Out:
# 15
# 7
# 40
# 3
# 1
# 100

# %% [markdown]
# ### 3.2 Float (float)
#
# Represents decimal numbers with double precision.

# %%
pi = 3.14159
scientific = 1.5e-4
# 1.5 * 10^-4
# = 0.00015

negative_float = -2.5

print(3.14 + 2.86)
print(10.0 / 3.0)
print(round(3.14159, 2))


# working with infinity
infinity = float('inf')
not_a_number = float('nan')

# math module...
# Out:
# 6.0
# 3.3333333333333335
# 3.14

# %% [markdown]
# ### 3.3 Complex (complex)
#
# Represents complex numbers with real and imaginary parts.

# %%
z1 = 3 + 4j
z2 = complex(2, -1)
z3 = 6j

# %%
print(z1.real)
print(z1.imag)
# Out:
# 3.0
# 4.0

# %%
# operations

print(z1 + z2)
print(z1 * z2)
print(abs(z1))
print(z1.conjugate())
# Out:
# (5+3j)
# (10+5j)
# 5.0
# (3-4j)

# %% [markdown]
# ## 4. Text Data Type
#
# ### 4.1 String (str)
#
# Represents sequences of Unicode characters.

# %%
# TASK: Unicode, utf8, utf16... encoding

# String creation
name = "Alice"
message = 'Hello, World!'
multiline = """This is a
multiline string. E.g., Alice's bag"""

# %%
# strings methods
text = "Python Programming"
print(text.upper())
print(text.lower())
print(text.split())
print(text.replace("Python", "Java"))
print(text.find("gram"))
print(len(text))
# Out:
# PYTHON PROGRAMMING
# python programming
# ['Python', 'Programming']
# Java Programming
# 10
# 18

# %%
# String slicing
word = "Python"
print(word[0])
print(word[-1])
print(word[0:2])
print(word[::2])
# Out:
# P
# n
# Py
# Pto

# %% [markdown]
# ### 4.2 String Operations and Methods

# %%
text = "Hello123"
print(text.isalnum())
print(text.isalpha())
print(text.isdigit())
print(text.islower())
print(text.isupper())
# Out:
# True
# False
# False
# False
# False

# %%
sentence = "  hello world . welcome to python training.  "
print(sentence.strip())
print(sentence.strip().capitalize())
print(sentence.title())
# Out:
# hello world . welcome to python training.
# Hello world . welcome to python training.
#   Hello World . Welcome To Python Training.

# %%
print('HELLO WORLD'.capitalize())
print('hello world'.capitalize())
print('heLlO woRld'.capitalize())
# Out:
# Hello world
# Hello world
# Hello world

# %%
words = ['Python', 'is', 'awesome!']

" ".join(words)
# Out:
# 'Python is awesome!'

# %% [markdown]
# ## 5. Boolean Data Type
#
# ### 5.1 Boolean (bool)
#
# Represents logical values: True or False.

# %%
is_valid = True
is_complete = False

# Boolean operations
print(True and False)
print(True or False)
print(not True)
# Out:
# False
# True
# False

# %%
# Comparison operations return booleans
print(5 > 3)
print(10 == 10)
print("hello" != "world")
# Out:
# True
# True
# True

# %%
# Truthiness in Python
# Falsy values: False, 0, 0.0, "", [], {}, None
print(bool(0))
print(bool([]))
print(bool(""))
print(bool(None))
# Out:
# False
# False
# False
# False

# %%
# Truthy values: everything else
print(bool(1))
print(bool([1, 2, 3]))
print(bool("hello"))
# Out:
# True
# True
# True

# %% [markdown]
# ## 6. Sequence Data Types
#
# ### 6.1 List (list)
#
# Ordered, mutable collections of items.

# %%
numbers = [1, 2, 3, 4, 5]
empty_list = []
nested = [[1, 2], [3, 4], [5, 6]]
mixed = [1, "hello", 3.14, True]


# List methods
fruits = ["apple", "banana", "orange"]
fruits.append("grape")
fruits
# Out:
# ['apple', 'banana', 'orange', 'grape']

# %%
fruits.insert(1, "cherry")
fruits
# Out:
# ['apple', 'cherry', 'banana', 'orange', 'grape']

# %%
fruits.remove("banana")
fruits
# Out:
# ['apple', 'cherry', 'orange', 'grape']

# %%
popped = fruits.pop()
popped
# Out:
# 'grape'

# %%
fruits.sort()   # in-place
fruits
# Out:
# ['apple', 'cherry', 'orange']

# %%
fruits.reverse() # in-place
fruits
# Out:
# ['orange', 'cherry', 'apple']

# %%
nested = [[1, 'string..'], [3, 4.5], [True, "Archita"]]

for item in nested:
    print(item[0], item[1] )
# Out:
# 1 string..
# 3 4.5
# True Archita

# %%
# list operations
print(len(fruits))
print("apple" in fruits)
print(fruits[0])
print(fruits[1:3])
# Out:
# 3
# True
# orange
# ['cherry', 'apple']

# %%
## list comprehensions

# %% [markdown]
# ### 6.2 Tuple (tuple)
#
# Ordered, immutable collections of items.

# %%
point = (3, 4)
colors = ("red", "green", "blue")
single_item = (42,)
empty_tuple = ()

# %%
s = 12, 13, 15

print(type(s))
# Out:
# <class 'tuple'>

# %%
# Tuple operations
print(point[0])
print(len(colors))
print("red" in colors)
# Out:
# 3
# 3
# True

# %%
# Tuple unpacking
x, y = point
print(f"x={x}, y={y}")
# Out:
# x=3, y=4

# %%
# Multiple assignment
a, b, c = colors
print(a, b, c)
# Out:
# red green blue

# %%
# Tuple methods
numbers = (1, 2, 3, 2, 2, 4)
print(numbers.count(2))
print(numbers.index(3))
# Out:
# 3
# 2

# %%
colors_tuple = ("red", "green", "blue")
colors_list = ["red", "green", "blue"]

# %%
colors_list[0] = 'black'
colors_list
# Out:
# ['black', 'green', 'blue']

# %%
# colors_tuple[0] = 'black'
# colors_tuple

# %% [markdown]
# ### 6.3 Range (range)
#
# Represents an immutable sequence of numbers.

# %%
r1 = range(5)
r2 = range(1, 6)
r3 = range(0, 10, 2)

print(type(r3))
print(list(r3))

print(len(r2))
print(3 in r2)
# Out:
# <class 'range'>
# [0, 2, 4, 6, 8]
# 5
# True

# %%
# Common usage in loops
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## 7. Mapping Data Type
#
# ### 7.1 Dictionary (dict)
#
# Unordered collections of key-value pairs.

# %%
dict_sample = {'k': 'value', 'k2':'value2'}
person = {"name": "Alice", "age": 30, "city": "New York"}
empty_dict = {}
mixed_keys = {1: "one", "two": 2, (3, 4): "tuple key"}

# TASK: understand why list cannot be a key in dict

# lookup tables, ({'student_name:scores}), params = {'host':'hostname', 'port':'3306'},

print(person["name"])
print(person.get("age"))
print(person.get("height", 0))
# Out:
# Alice
# 30
# 0

# %%
# Dictionary methods
person["email"] = "alice@example.com"
del person["city"]

# %%
keys = person.keys()

# %%
keys
# Out:
# dict_keys(['name', 'age', 'email'])

# %%
values = person.values()
values
# Out:
# dict_values(['Alice', 30, 'alice@example.com'])

# %%
items = person.items()
items
# Out:
# dict_items([('name', 'Alice'), ('age', 30), ('email', 'alice@example.com')])

# %%
for k, v in person.items():
    print(f"key is {k} and value is {v}")
# Out:
# key is name and value is Alice
# key is age and value is 30
# key is email and value is alice@example.com

# %%
for attribute, value in person.items():
    print(f"key is {attribute} and value is {value}")
# Out:
# key is name and value is Alice
# key is age and value is 30
# key is email and value is alice@example.com

# %%
for key in person:
    print(key, person[key])
# Out:
# name Alice
# age 30
# email alice@example.com

# %% [markdown]
# ## 8. Set Data Types
#
# ### 8.1 Set (set)
#
# Unordered collections of unique elements.

# %%
numbers = {1, 2, 3, 4, 5}

colors = set(["red", "green", "blue", "red"])
colors
# Out:
# {'blue', 'green', 'red'}

# %%
empty_set = set()

# %%
# Set operations
numbers.add(6)
numbers.remove(1)
numbers.discard(10)

# %%
numbers
# Out:
# {2, 3, 4, 5, 6}

# %%
# Set mathematical operations
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

print(set1 | set2) # union {1,2,3,4,5,6}
print(set1 & set2) # intersection {3,4}
print(set1 - set2) # difference {1, 2} A -B
print(set1 ^ set2) # symmetric difference {1, 2, 5, 6}
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {1, 2, 5, 6}
